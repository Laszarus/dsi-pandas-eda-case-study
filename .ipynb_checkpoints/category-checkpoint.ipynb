# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
us_data = pd.read_csv('data/youtube-new/USvideos.csv')
gb_data = pd.read_csv('data/youtube-new/GBvideos.csv')
# mx_data = pd.read_csv('data/youtube-new/MXvideos.csv')
# kr_data = pd.read_csv('data/youtube-new/KRvideos.csv')
# jp_data = pd.read_csv('data/youtube-new/JPvideos.csv')
# in_data = pd.read_csv('data/youtube-new/INvideos.csv')
fr_data = pd.read_csv('data/youtube-new/FRvideos.csv')
de_data = pd.read_csv('data/youtube-new/DEvideos.csv')
ca_data = pd.read_csv('data/youtube-new/CAvideos.csv')

# %%
gb_data
# Out:
#           video_id trending_date  \
# 0      Jw1Y-zhQURU      17.14.11
# 1      3s1rvMFUweQ      17.14.11
# 2      n1WpP7iowLc      17.14.11
# 3      PUTEiSjKwJU      17.14.11
# 4      rHwDegptbI4      17.14.11
# 5      AumaWl0TNBo      17.14.11
# 6      2Vv-BfVoq4g      17.14.11
# 7      -N5eucPMTTc      17.14.11
# 8      LMCuKltaY3M      17.14.11
# 9      9t9u_yPEidY      17.14.11
# 10     ONQ-fAp5X64      17.14.11
# 11     Dlwf5u2BLAg      17.14.11
# 12     NVCqz2BDfcQ      17.14.11
# 13     MyEqfBkzESU      17.14.11
# 14     b4vTZx_AtHk      17.14.11
# 15     BsfhHKx6ajA      17.14.11
# 16     DIU3xPdhCBI      17.14.11
# 17     pz95u3UVpaM      17.14.11
# 18     jp9hK-jY6yY      17.14.11
# 19     gEHCXl4J9Qo      17.14.11
# 20     OWvCCu2t6Ts      17.14.11
# 21     6p-QzY5bxJ0      17.14.11
# 22     fiusxyygqGk      17.14.11
# 23     QOksZ8VogRw      17.14.11
# 24     lo5ERI5nPbM      17.14.11
# 25     Ja_GMU7-sjs      17.14.11
# 26     _6ViZ13mN9I      17.14.11
# ...

# %%
us_data[us_data['video_id'] == 'j4KvrAUjn6c']
# Out:
#           video_id trending_date                                       title  \
# 34550  j4KvrAUjn6c      18.14.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 34752  j4KvrAUjn6c      18.15.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 34901  j4KvrAUjn6c      18.15.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 34966  j4KvrAUjn6c      18.16.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 35180  j4KvrAUjn6c      18.17.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 35396  j4KvrAUjn6c      18.18.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 35600  j4KvrAUjn6c      18.19.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 35804  j4KvrAUjn6c      18.20.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 36035  j4KvrAUjn6c      18.21.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 36245  j4KvrAUjn6c      18.22.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 36453  j4KvrAUjn6c      18.23.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# ...

# %%
grpby_obj = us_data.groupby(['video_id'])

# %%
grpby_obj.count().sort_values(by = 'title', ascending = False).index[0]
# Out:
# 'j4KvrAUjn6c'

# %%
us_data[us_data['video_id'] == grpby_obj.count().sort_values(by = 'title', ascending = False).index[0]]['title']
# Out:
# 34550    WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 34752    WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 34901    WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 34966    WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 35180    WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 35396    WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 35600    WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 35804    WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 36035    WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 36245    WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 36453    WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 36661    WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 36868    WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 37080    WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 37291    WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 37493    WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 37694    WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 37899    WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# ...

# %%
fr_data.groupby(['video_id']).count().sort_values(by = 'title', ascending = False)
# Out:
#              trending_date  title  channel_title  category_id  publish_time  \
# video_id
# Rter-Np-Td0              6      6              6            6             6
# RcPik8IivHY              5      5              5            5             5
# CG9EGStW-nE              5      5              5            5             5
# aJOTlE1K90k              5      5              5            5             5
# lHz-0c2dMDA              5      5              5            5             5
# aGgU7O-z0Dg              5      5              5            5             5
# 2z3EUY1aXdY              5      5              5            5             5
# knf0PIXHFpg              5      5              5            5             5
# engRKCpYXnY              5      5              5            5             5
# TITlnMA7bH8              5      5              5            5             5
# m50utO7lnqI              5      5              5            5             5
# ...

# %%
us_category_df_ND = us_data[['video_id', 'category_id']].drop_duplicates()
us_category_df = us_data[['video_id', 'category_id']]
grpby_obj = us_category_df.groupby('video_id').count()
grpby_obj.sort_values(by = 'category_id', ascending = False)
us_trends = pd.merge(grpby_obj.sort_values(by = 'category_id', ascending = False), us_category_df_ND, on = 'video_id' )

# %%
gb_category_df_ND = gb_data[['video_id', 'category_id']].drop_duplicates()
gb_category_df = gb_data[['video_id', 'category_id']]
gb_grpby_obj = gb_category_df.groupby('video_id').count()
gb_grpby_obj.sort_values(by = 'category_id', ascending = False)
gb_trends = pd.merge(gb_grpby_obj.sort_values(by = 'category_id', ascending = False), gb_category_df_ND, on = 'video_id' )

# %%
fr_category_df_ND = fr_data[['video_id', 'category_id']].drop_duplicates()
fr_category_df = fr_data[['video_id', 'category_id']]
fr_grpby_obj = fr_category_df.groupby('video_id').count()
fr_grpby_obj.sort_values(by = 'category_id', ascending = False)
fr_trends = pd.merge(fr_grpby_obj.sort_values(by = 'category_id', ascending = False), fr_category_df_ND, on = 'video_id' )

# %%
de_category_df_ND = de_data[['video_id', 'category_id']].drop_duplicates()
de_category_df = de_data[['video_id', 'category_id']]
de_grpby_obj = de_category_df.groupby('video_id').count()
de_grpby_obj.sort_values(by = 'category_id', ascending = False)
de_trends = pd.merge(de_grpby_obj.sort_values(by = 'category_id', ascending = False), de_category_df_ND, on = 'video_id' )

# %%
ca_category_df_ND = ca_data[['video_id', 'category_id']].drop_duplicates()
ca_category_df = ca_data[['video_id', 'category_id']]
ca_grpby_obj = ca_category_df.groupby('video_id').count()
ca_grpby_obj.sort_values(by = 'category_id', ascending = False)
ca_trends = pd.merge(ca_grpby_obj.sort_values(by = 'category_id', ascending = False), ca_category_df_ND, on = 'video_id' )

# %%
frame_list = [us_trends[['video_id']], gb_trends[['video_id']], fr_trends[['video_id']], de_trends[['video_id']], ca_trends[['video_id']]]

# %%
sim_list = [[pd.merge(frame_list[i], frame_list[j], how='inner').count() for i in range(len(frame_list))] for j in range(len(frame_list))]
type(sim_list)
# Out:
# list

# %%
fig, ax = plt.subplots()
im = ax.imshow(harvest)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-115-63b07f09bb0a> in <module>
# ----> 1 fig, ax = plt.subplots()
#       2 im = ax.imshow(harvest)
#
# NameError: name 'plt' is not defined
