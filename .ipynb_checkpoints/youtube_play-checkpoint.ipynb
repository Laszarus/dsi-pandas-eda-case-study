# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
raw_us = pd.read_csv('data/youtube-new/USvideos.csv')
raw_us.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
df_us = raw_us[['video_id', 'trending_date', 'title', 'channel_title', 'category_id','publish_time', 'tags', 'views', 'likes', 'dislikes']]
df_us.info
# Out:
# <bound method DataFrame.info of           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# 5      gHZ1Qz0KiKM      17.14.11
# 6      39idVpFF7NQ      17.14.11
# 7      nc99ccSXST0      17.14.11
# 8      jr9QtXwC9vc      17.14.11
# 9      TUmyygCMMGA      17.14.11
# 10     9wRQljFNDW8      17.14.11
# 11     VifQlJit6A0      17.14.11
# 12     5E4ZBSInqUU      17.14.11
# 13     GgVmn66oK_A      17.14.11
# 14     TaTleo4cOs8      17.14.11
# 15     kgaO45SyaO4      17.14.11
# 16     ZAQs-ctOqXQ      17.14.11
# 17     YVfyYrEmzgM      17.14.11
# 18     eNSN6qet1kE      17.14.11
# 19     B5HORANmzHw      17.14.11
# 20     vU14JY3x81A      17.14.11
# 21     6VhU_T463sU      17.14.11
# 22     _-aDHxoblr4      17.14.11
# 23     JBZTZZAcFTw      17.14.11
# 24     lZ68j2J_GOM      17.14.11
# 25     dRpNZV18N_g      17.14.11
# ...

# %%
df_us.sort_values('publish_time', ascending = True)
#multiple rows with same video. Not apparent why. lets find out
# Out:
#           video_id trending_date  \
# 16294  MJO3FmmFuh4      18.05.02
# 10921  UQtt9I6c-YM      18.07.01
# 11150  UQtt9I6c-YM      18.08.01
# 10710  UQtt9I6c-YM      18.06.01
# 11375  UQtt9I6c-YM      18.09.01
# 2979   wFEAoF7RC7Y      17.28.11
# 2526   wFEAoF7RC7Y      17.26.11
# 2750   wFEAoF7RC7Y      17.27.11
# 2311   wFEAoF7RC7Y      17.25.11
# 2775   Y8JGfi4MJ8k      17.27.11
# 2994   Y8JGfi4MJ8k      17.28.11
# 2553   Y8JGfi4MJ8k      17.26.11
# 1364   rO_mAQC9bv0      17.20.11
# 1136   rO_mAQC9bv0      17.19.11
# 6597   2vQ_fnlvvr8      17.16.12
# 12740  tYFYoLEO0dM      18.18.01
# 12993  tYFYoLEO0dM      18.19.01
# 11562  c_KdAO6MqiM      18.12.01
# 8480   -37nIo_tLnk      17.26.12
# 9983   -37nIo_tLnk      18.02.01
# 9136   -37nIo_tLnk      17.29.12
# 9775   -37nIo_tLnk      18.01.01
# 9571   -37nIo_tLnk      17.31.12
# 8694   -37nIo_tLnk      17.27.12
# 9351   -37nIo_tLnk      17.30.12
# 8920   -37nIo_tLnk      17.28.12
# 250    qC0I5PEhkJo      17.15.11
# ...

# %%
#raw_us.set_index('video_id').loc['Y8JGfi4MJ8k']
raw_us.set_index('video_id').loc['UQtt9I6c-YM']
#looks like the data is containing more than we thought
#holds data of all trending youtube videos and their status over time
# Out:
#             trending_date                        title      channel_title  \
# video_id
# UQtt9I6c-YM      18.06.01  Kramer vs Kramer-Clou Scene  Livia Giustiniani
# UQtt9I6c-YM      18.07.01  Kramer vs Kramer-Clou Scene  Livia Giustiniani
# UQtt9I6c-YM      18.08.01  Kramer vs Kramer-Clou Scene  Livia Giustiniani
# UQtt9I6c-YM      18.09.01  Kramer vs Kramer-Clou Scene  Livia Giustiniani
#
#              category_id              publish_time  \
# video_id
# UQtt9I6c-YM            1  2008-04-05T18:22:40.000Z
# UQtt9I6c-YM            1  2008-04-05T18:22:40.000Z
# UQtt9I6c-YM            1  2008-04-05T18:22:40.000Z
# UQtt9I6c-YM            1  2008-04-05T18:22:40.000Z
#
#                                                           tags  views  likes  \
# video_id
# UQtt9I6c-YM  Meryl|"Streep"|"kramer"|"vs"|"dustin"|"hoffman...  49942     46
# UQtt9I6c-YM  Meryl|"Streep"|"kramer"|"vs"|"dustin"|"hoffman...  50030     46
# ...

# %%
#Now that we have a better idea of what's going on in the data let's go back to df_us
df_us.sort_values(['video_id', 'trending_date','views'])
# Out:
#           video_id trending_date  \
# 39169  -0CMnp02rNY      18.06.06
# 39375  -0CMnp02rNY      18.07.06
# 39584  -0CMnp02rNY      18.08.06
# 39795  -0CMnp02rNY      18.09.06
# 40007  -0CMnp02rNY      18.10.06
# 40208  -0CMnp02rNY      18.11.06
# 15457  -0NYY8cqdiQ      18.01.02
# 31992  -1Hm41N0dUs      18.01.05
# 31553  -1Hm41N0dUs      18.29.04
# 31773  -1Hm41N0dUs      18.30.04
# 3483   -1yT-K3c6YI      17.01.12
# 3711   -1yT-K3c6YI      17.02.12
# 3019   -1yT-K3c6YI      17.29.11
# 3237   -1yT-K3c6YI      17.30.11
# 90     -2RVw2_QyxQ      17.14.11
# 346    -2RVw2_QyxQ      17.15.11
# 584    -2RVw2_QyxQ      17.16.11
# 31158  -2aVkGcI7ZA      18.27.04
# 31369  -2aVkGcI7ZA      18.28.04
# 31576  -2aVkGcI7ZA      18.29.04
# 31798  -2aVkGcI7ZA      18.30.04
# 7220   -2b4qSoMnKE      17.20.12
# 7431   -2b4qSoMnKE      17.21.12
# 17996  -2wRFv-mScQ      18.14.02
# 18234  -2wRFv-mScQ      18.15.02
# 18461  -2wRFv-mScQ      18.16.02
# 18683  -2wRFv-mScQ      18.17.02
# ...

# %%
id_keys = set(df_us['video_id'])
len(id_keys)
# Out:
# 6351

# %%
df_counts = df_us.groupby(['video_id', 'trending_date','views'])
df_counts

# %%
df_counts = df_us.set_index(['video_id']).groupby('video_id').count()
df_counts.reset_index(inplace = True)

df_id_counts = pd.DataFrame([df_counts['video_id'],df_counts['views']]).T
df_id_counts.columns = ['video_id','total_views']
df_id_counts.head()
# Out:
#       video_id total_views
# 0  -0CMnp02rNY           6
# 1  -0NYY8cqdiQ           1
# 2  -1Hm41N0dUs           3
# 3  -1yT-K3c6YI           4
# 4  -2RVw2_QyxQ           3

# %%
df_id_counts.columns
# Out:
# Index(['video_id', 'total_views'], dtype='object')

# %%
df_id_counts.
# Out:
#   File "<ipython-input-11-a574b6e032ae>", line 1
#     df_id_counts.
#                  ^
# SyntaxError: invalid syntax

# %%
days_trending = []
for key in id_keys:
    days_trending.append(df_us.groupby('video_id').count())
days_trending

# %% [markdown]
# ### Second run

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
raw_us = pd.read_csv('data/youtube-new/USvideos.csv')
raw_us.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
df_us = raw_us[['video_id', 'trending_date', 'title', 'channel_title', 'category_id','publish_time', 'tags', 'views', 'likes', 'dislikes']]
df_us.info
# Out:
# <bound method DataFrame.info of           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# 5      gHZ1Qz0KiKM      17.14.11
# 6      39idVpFF7NQ      17.14.11
# 7      nc99ccSXST0      17.14.11
# 8      jr9QtXwC9vc      17.14.11
# 9      TUmyygCMMGA      17.14.11
# 10     9wRQljFNDW8      17.14.11
# 11     VifQlJit6A0      17.14.11
# 12     5E4ZBSInqUU      17.14.11
# 13     GgVmn66oK_A      17.14.11
# 14     TaTleo4cOs8      17.14.11
# 15     kgaO45SyaO4      17.14.11
# 16     ZAQs-ctOqXQ      17.14.11
# 17     YVfyYrEmzgM      17.14.11
# 18     eNSN6qet1kE      17.14.11
# 19     B5HORANmzHw      17.14.11
# 20     vU14JY3x81A      17.14.11
# 21     6VhU_T463sU      17.14.11
# 22     _-aDHxoblr4      17.14.11
# 23     JBZTZZAcFTw      17.14.11
# 24     lZ68j2J_GOM      17.14.11
# 25     dRpNZV18N_g      17.14.11
# ...

# %%
df_us.sort_values(['video_id','views'])
# Out:
#           video_id trending_date  \
# 39169  -0CMnp02rNY      18.06.06
# 39375  -0CMnp02rNY      18.07.06
# 39584  -0CMnp02rNY      18.08.06
# 39795  -0CMnp02rNY      18.09.06
# 40007  -0CMnp02rNY      18.10.06
# 40208  -0CMnp02rNY      18.11.06
# 15457  -0NYY8cqdiQ      18.01.02
# 31553  -1Hm41N0dUs      18.29.04
# 31773  -1Hm41N0dUs      18.30.04
# 31992  -1Hm41N0dUs      18.01.05
# 3019   -1yT-K3c6YI      17.29.11
# 3237   -1yT-K3c6YI      17.30.11
# 3483   -1yT-K3c6YI      17.01.12
# 3711   -1yT-K3c6YI      17.02.12
# 90     -2RVw2_QyxQ      17.14.11
# 346    -2RVw2_QyxQ      17.15.11
# 584    -2RVw2_QyxQ      17.16.11
# 31158  -2aVkGcI7ZA      18.27.04
# 31369  -2aVkGcI7ZA      18.28.04
# 31576  -2aVkGcI7ZA      18.29.04
# 31798  -2aVkGcI7ZA      18.30.04
# 7220   -2b4qSoMnKE      17.20.12
# 7431   -2b4qSoMnKE      17.21.12
# 17996  -2wRFv-mScQ      18.14.02
# 18234  -2wRFv-mScQ      18.15.02
# 18461  -2wRFv-mScQ      18.16.02
# 18683  -2wRFv-mScQ      18.17.02
# ...

# %%
df_counts = df_us.groupby(['video_id','views'])
df_counts

# %%
df_counts = df_us.set_index(['video_id']).groupby('video_id').sum()
df_counts.reset_index(inplace = True)

df_id_views = pd.DataFrame([df_counts['video_id'],df_counts['views']]).T
df_id_views.columns = ['video_id','views']
df_id_views.head(10)
# Out:
#       video_id     views
# 0  -0CMnp02rNY   4134702
# 1  -0NYY8cqdiQ    563746
# 2  -1Hm41N0dUs   5507675
# 3  -1yT-K3c6YI    777243
# 4  -2RVw2_QyxQ    208304
# 5  -2aVkGcI7ZA   6674574
# 6  -2b4qSoMnKE    376397
# 7  -2wRFv-mScQ   3571583
# 8  -35jibKqbEo  11810739
# 9  -37nIo_tLnk     24546

# %%
df_counts = df_us.set_index(['video_id']).groupby('video_id').count()
df_counts.reset_index(inplace = True)

df_id_counts = pd.DataFrame([df_counts['video_id'],
                             pd.to_numeric(df_counts['views']),
                             pd.to_numeric(df_id_views['views'])
                            ]).T
df_id_counts.columns = ['video_id','days_trending','views']
# df_id_counts = pd.DataFrame([df_id_counts['video_id'],
#                              pd.to_numeric(df_id_counts['days_trending']),
#                              pd.to_numeric(df_id_counts['views'])
#                             ])
df_id_counts['views'] = pd.to_numeric(df_id_counts['views'])
df_id_counts['days_trending'] = pd.to_numeric(df_id_counts['days_trending'])

df_id_counts

# %%
df_id_views['views']
# Out:
# 0         4134702
# 1          563746
# 2         5507675
# 3          777243
# 4          208304
# 5         6674574
# 6          376397
# 7         3571583
# 8        11810739
# 9           24546
# 10         385104
# 11        3408965
# 12        1293983
# 13        5084887
# 14        9337953
# 15        4504151
# 16        2043346
# 17       11616078
# 18       46887692
# 19         252542
# 20        1371506
# 21         296615
# 22         587619
# 23        5572363
# 24      748060352
# 25        4940862
# 26        3175383
# 27       55516806
# 28        7408557
# 29        3277782
#           ...
# 6321      2163388
# 6322     45449913
# 6323        19420
# 6324      9681377
# 6325      2755680
# 6326      3817650
# 6327          748
# 6328     19759150
# 6329       431772
# 6330       470211
# 6331       935079
# 6332     71146335
# 6333      2708371
# 6334    122400297
# 6335      1648886
# 6336       180064
# 6337       791119
# 6338       142863
# 6339      7334058
# ...

# %%
df_counts = df_us.set_index(['video_id']).groupby('video_id').count()
df_counts.reset_index(inplace = True)

df_id_counts = pd.DataFrame([df_counts['video_id'],
                             pd.to_numeric(df_counts['views']),
                             pd.to_numeric(df_id_views['views'])
                            ]).T
df_id_counts.columns = ['video_id','days_trending','views']
# df_id_counts = pd.DataFrame([df_id_counts['video_id'],
#                              pd.to_numeric(df_id_counts['days_trending']),
#                              pd.to_numeric(df_id_counts['views'])
#                             ])
df_id_counts['views'] = pd.to_numeric(df_id_counts['views'])
df_id_counts['days_trending'] = pd.to_numeric(df_id_counts['days_trending'])

df_id_counts
# Out:
#          video_id  days_trending      views
# 0     -0CMnp02rNY              6    4134702
# 1     -0NYY8cqdiQ              1     563746
# 2     -1Hm41N0dUs              3    5507675
# 3     -1yT-K3c6YI              4     777243
# 4     -2RVw2_QyxQ              3     208304
# 5     -2aVkGcI7ZA              4    6674574
# 6     -2b4qSoMnKE              2     376397
# 7     -2wRFv-mScQ              4    3571583
# 8     -35jibKqbEo              8   11810739
# 9     -37nIo_tLnk              8      24546
# 10    -39ysKKpE7I              1     385104
# 11    -3h4Xt9No9o             10    3408965
# 12    -3nEHRN6IPg              5    1293983
# 13    -4s2MeUgduo             13    5084887
# 14    -5aaJJQFvOg             11    9337953
# 15    -66xHRJSPxs              4    4504151
# 16    -7AZX5Xtiks              4    2043346
# 17    -7UzyXO-mzk              6   11616078
# 18    -7_ATlZ-zMc             15   46887692
# 19    -8ZHXaGILlc              1     252542
# ...

# %%
df_id_counts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6351 entries, 0 to 6350
# Data columns (total 3 columns):
# video_id         6351 non-null object
# days_trending    6351 non-null int64
# views            6351 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 148.9+ KB

# %%
ax = df_id_counts.plot(kind = 'scatter', 
                  x = 'days_trending', 
                  y = 'views', 
                  logy = True,
                    figsize = (15,10))
ax.set_xlabel('Days Trending')
ax.set_ylabel('Views (Log)')
ax.set_title('Days trending vs Views')
# Out:
# Text(0.5,1,'Days trending vs Views')
